# %%
import seaborn as sns

# %%
def func(x):
    return (x + 3)**2

def derivative(x):
    return 2 * (x + 3)

# %%
gd = []
def gradient_descent(start, learning_steps, n_iterations):
    x = start
    for i in range(n_iterations):
        grad = derivative(x)
        x = x - learning_steps * grad
        gd.append(x)
    return x

# %%
start = 2
learning_steps = 0.1
n_iterations = 50

min_value = gradient_descent(start, learning_steps, n_iterations)
print("The minimum value x: ", min_value)
# Out:
# The minimum value x:  -2.9999286376153647

# %%
sns.scatterplot(gd)
# Out:
# <Axes: >
